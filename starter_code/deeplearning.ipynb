# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Remove the space for 'FALSE POSITIVE'
new = df["koi_disposition"] == "FALSE POSITIVE"
df.loc[new, "koi_disposition"] = "False_Positive"
df["koi_disposition"]
# Out:
# 0            CONFIRMED
# 1       False_Positive
# 2       False_Positive
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    False_Positive
# 6987    False_Positive
# 6988         CANDIDATE
# 6989    False_Positive
# 6990    False_Positive
# Name: koi_disposition, Length: 6991, dtype: object

# %% [markdown]
# # Create a Train Test Split

# %%
# Asssign the X and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Split the data into training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6080              1              0              0              0   12.496435
# 3001              0              0              0              0   11.615625
# 570               0              1              0              0   10.980246
# 4897              1              0              0              0  466.908240
# 625               0              1              1              1    1.061933
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6080     2.213000e-04    -2.213000e-04   132.035800          0.014300
# 3001     1.528000e-04    -1.528000e-04   131.968430          0.008230
# 570      6.930000e-07    -6.930000e-07   137.137607          0.000053
# 4897     1.194000e-02    -1.194000e-02   136.373100          0.019000
# 625      1.250000e-06    -1.250000e-06   133.850441          0.000978
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6080         -0.014300  ...            -286      3.805           0.390
# 3001         -0.008230  ...             -72      4.083           0.368
# 570          -0.000053  ...            -159      4.462           0.098
# 4897         -0.019000  ...            -146      4.456           0.102
# 625          -0.000978  ...            -167      3.975           0.259
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6080          -0.130     2.730          0.535         -1.248  289.23080
# 3001          -0.092     1.453          0.218         -0.510  293.52756
# 570           -0.182     0.897          0.238         -0.119  282.79764
# 4897          -0.361     0.867          0.448         -0.103  297.65436
# 625           -0.111     1.851          0.383         -0.575  288.90253
#
#             dec  koi_kepmag
# 6080  44.412483      13.054
# 3001  41.111439      15.162
# 570   43.578129      14.212
# 4897  43.178551      15.202
# 625   44.632992      12.953
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing

# %%
# Fit data to the MinMax Scaler
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Create a Deep Learning Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Create the model
model = Sequential()
# Add two layers of nodes
model.add(Dense(units=120, activation='relu', input_dim=40))
model.add(Dense(units=120, activation='relu'))
# Add the output layer
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 120)               4920
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               14520
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 363
# =================================================================
# Total params: 19,803
# Trainable params: 19,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 1s - loss: 0.5607 - accuracy: 0.7309
# Epoch 2/100
# 164/164 - 0s - loss: 0.3720 - accuracy: 0.8150
# Epoch 3/100
# 164/164 - 0s - loss: 0.3567 - accuracy: 0.8209
# Epoch 4/100
# 164/164 - 0s - loss: 0.3468 - accuracy: 0.8287
# Epoch 5/100
# 164/164 - 0s - loss: 0.3416 - accuracy: 0.8343
# Epoch 6/100
# 164/164 - 0s - loss: 0.3312 - accuracy: 0.8451
# Epoch 7/100
# 164/164 - 0s - loss: 0.3312 - accuracy: 0.8425
# Epoch 8/100
# 164/164 - 0s - loss: 0.3169 - accuracy: 0.8589
# Epoch 9/100
# 164/164 - 0s - loss: 0.3284 - accuracy: 0.8480
# Epoch 10/100
# 164/164 - 0s - loss: 0.3172 - accuracy: 0.8531
# Epoch 11/100
# 164/164 - 0s - loss: 0.3099 - accuracy: 0.8573
# Epoch 12/100
# 164/164 - 0s - loss: 0.3041 - accuracy: 0.8608
# Epoch 13/100
# 164/164 - 0s - loss: 0.2995 - accuracy: 0.8690
# Epoch 14/100
# 164/164 - 0s - loss: 0.2987 - accuracy: 0.8680
# Epoch 15/100
# 164/164 - 0s - loss: 0.2978 - accuracy: 0.8655
# Epoch 16/100
# 164/164 - 0s - loss: 0.2942 - accuracy: 0.8659
# Epoch 17/100
# 164/164 - 0s - loss: 0.2892 - accuracy: 0.8749
# Epoch 18/100
# 164/164 - 0s - loss: 0.2881 - accuracy: 0.8714
# Epoch 19/100
# 164/164 - 0s - loss: 0.2883 - accuracy: 0.8732
# Epoch 20/100
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8735
# Epoch 21/100
# 164/164 - 0s - loss: 0.2879 - accuracy: 0.8735
# Epoch 22/100
# 164/164 - 0s - loss: 0.2836 - accuracy: 0.8751
# Epoch 23/100
# 164/164 - 0s - loss: 0.2788 - accuracy: 0.8819
# Epoch 24/100
# 164/164 - 0s - loss: 0.2843 - accuracy: 0.8753
# Epoch 25/100
# 164/164 - 0s - loss: 0.2729 - accuracy: 0.8846
# Epoch 26/100
# 164/164 - 0s - loss: 0.2750 - accuracy: 0.8812
# Epoch 27/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8800
# Epoch 28/100
# 164/164 - 0s - loss: 0.2719 - accuracy: 0.8816
# Epoch 29/100
# 164/164 - 0s - loss: 0.2769 - accuracy: 0.8781
# Epoch 30/100
# 164/164 - 0s - loss: 0.2716 - accuracy: 0.8831
# Epoch 31/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8777
# Epoch 32/100
# 164/164 - 0s - loss: 0.2665 - accuracy: 0.8863
# Epoch 33/100
# 164/164 - 0s - loss: 0.2673 - accuracy: 0.8833
# Epoch 34/100
# 164/164 - 0s - loss: 0.2684 - accuracy: 0.8863
# Epoch 35/100
# 164/164 - 0s - loss: 0.2714 - accuracy: 0.8835
# Epoch 36/100
# 164/164 - 0s - loss: 0.2613 - accuracy: 0.8873
# Epoch 37/100
# 164/164 - 0s - loss: 0.2616 - accuracy: 0.8896
# Epoch 38/100
# 164/164 - 0s - loss: 0.2609 - accuracy: 0.8877
# Epoch 39/100
# 164/164 - 0s - loss: 0.2594 - accuracy: 0.8879
# Epoch 40/100
# 164/164 - 0s - loss: 0.2584 - accuracy: 0.8863
# Epoch 41/100
# 164/164 - 0s - loss: 0.2567 - accuracy: 0.8892
# Epoch 42/100
# 164/164 - 0s - loss: 0.2600 - accuracy: 0.8848
# Epoch 43/100
# 164/164 - 0s - loss: 0.2565 - accuracy: 0.8888
# Epoch 44/100
# 164/164 - 0s - loss: 0.2538 - accuracy: 0.8922
# Epoch 45/100
# 164/164 - 0s - loss: 0.2495 - accuracy: 0.8911
# Epoch 46/100
# 164/164 - 0s - loss: 0.2535 - accuracy: 0.8915
# Epoch 47/100
# 164/164 - 0s - loss: 0.2501 - accuracy: 0.8930
# Epoch 48/100
# 164/164 - 0s - loss: 0.2533 - accuracy: 0.8894
# Epoch 49/100
# 164/164 - 0s - loss: 0.2505 - accuracy: 0.8945
# Epoch 50/100
# 164/164 - 0s - loss: 0.2533 - accuracy: 0.8888
# Epoch 51/100
# 164/164 - 0s - loss: 0.2455 - accuracy: 0.8934
# Epoch 52/100
# 164/164 - 0s - loss: 0.2490 - accuracy: 0.8930
# Epoch 53/100
# 164/164 - 0s - loss: 0.2443 - accuracy: 0.8922
# Epoch 54/100
# 164/164 - 0s - loss: 0.2509 - accuracy: 0.8888
# Epoch 55/100
# 164/164 - 0s - loss: 0.2449 - accuracy: 0.8941
# Epoch 56/100
# 164/164 - 0s - loss: 0.2425 - accuracy: 0.8962
# Epoch 57/100
# 164/164 - 0s - loss: 0.2431 - accuracy: 0.8955
# Epoch 58/100
# 164/164 - 0s - loss: 0.2395 - accuracy: 0.8962
# Epoch 59/100
# 164/164 - 0s - loss: 0.2464 - accuracy: 0.8930
# Epoch 60/100
# 164/164 - 0s - loss: 0.2485 - accuracy: 0.8896
# Epoch 61/100
# 164/164 - 0s - loss: 0.2383 - accuracy: 0.8983
# Epoch 62/100
# 164/164 - 0s - loss: 0.2419 - accuracy: 0.8947
# Epoch 63/100
# 164/164 - 0s - loss: 0.2401 - accuracy: 0.8947
# Epoch 64/100
# 164/164 - 0s - loss: 0.2420 - accuracy: 0.8972
# Epoch 65/100
# 164/164 - 0s - loss: 0.2380 - accuracy: 0.8957
# Epoch 66/100
# 164/164 - 0s - loss: 0.2410 - accuracy: 0.8941
# Epoch 67/100
# 164/164 - 0s - loss: 0.2411 - accuracy: 0.8940
# Epoch 68/100
# 164/164 - 0s - loss: 0.2352 - accuracy: 0.8987
# Epoch 69/100
# 164/164 - 0s - loss: 0.2348 - accuracy: 0.8981
# Epoch 70/100
# 164/164 - 0s - loss: 0.2392 - accuracy: 0.8968
# Epoch 71/100
# 164/164 - 0s - loss: 0.2308 - accuracy: 0.8999
# Epoch 72/100
# 164/164 - 0s - loss: 0.2296 - accuracy: 0.9006
# Epoch 73/100
# 164/164 - 0s - loss: 0.2338 - accuracy: 0.8989
# Epoch 74/100
# 164/164 - 0s - loss: 0.2324 - accuracy: 0.8976
# Epoch 75/100
# 164/164 - 0s - loss: 0.2371 - accuracy: 0.8938
# Epoch 76/100
# 164/164 - 0s - loss: 0.2339 - accuracy: 0.9002
# Epoch 77/100
# 164/164 - 0s - loss: 0.2354 - accuracy: 0.8978
# Epoch 78/100
# 164/164 - 0s - loss: 0.2346 - accuracy: 0.8981
# Epoch 79/100
# 164/164 - 0s - loss: 0.2311 - accuracy: 0.8978
# Epoch 80/100
# 164/164 - 0s - loss: 0.2352 - accuracy: 0.8993
# Epoch 81/100
# 164/164 - 0s - loss: 0.2269 - accuracy: 0.9016
# Epoch 82/100
# 164/164 - 0s - loss: 0.2335 - accuracy: 0.8981
# Epoch 83/100
# 164/164 - 0s - loss: 0.2274 - accuracy: 0.8985
# Epoch 84/100
# 164/164 - 0s - loss: 0.2283 - accuracy: 0.9027
# Epoch 85/100
# 164/164 - 0s - loss: 0.2329 - accuracy: 0.8972
# Epoch 86/100
# 164/164 - 0s - loss: 0.2237 - accuracy: 0.9050
# Epoch 87/100
# 164/164 - 0s - loss: 0.2258 - accuracy: 0.9027
# Epoch 88/100
# 164/164 - 0s - loss: 0.2340 - accuracy: 0.8980
# Epoch 89/100
# 164/164 - 0s - loss: 0.2316 - accuracy: 0.8970
# Epoch 90/100
# 164/164 - 0s - loss: 0.2286 - accuracy: 0.8995
# Epoch 91/100
# 164/164 - 0s - loss: 0.2221 - accuracy: 0.9043
# Epoch 92/100
# 164/164 - 0s - loss: 0.2242 - accuracy: 0.9025
# Epoch 93/100
# 164/164 - 0s - loss: 0.2220 - accuracy: 0.9031
# Epoch 94/100
# 164/164 - 0s - loss: 0.2256 - accuracy: 0.9002
# Epoch 95/100
# 164/164 - 0s - loss: 0.2349 - accuracy: 0.8928
# Epoch 96/100
# 164/164 - 0s - loss: 0.2261 - accuracy: 0.9006
# Epoch 97/100
# 164/164 - 0s - loss: 0.2253 - accuracy: 0.9050
# Epoch 98/100
# 164/164 - 0s - loss: 0.2227 - accuracy: 0.9025
# Epoch 99/100
# 164/164 - 0s - loss: 0.2182 - accuracy: 0.9025
# Epoch 100/100
# 164/164 - 0s - loss: 0.2207 - accuracy: 0.9056

# %% [markdown]
# # Quantify Model

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2276 - accuracy: 0.8976
# Normal Neural Network - Loss: 0.22760841250419617, Accuracy: 0.8975972533226013

# %% [markdown]
# # Model Predictions

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CANDIDATE' 'False_Positive' 'False_Positive' 'False_Positive'
#  'CANDIDATE']
# Actual Labels: ['CANDIDATE', 'False_Positive', 'False_Positive', 'False_Positive', 'CANDIDATE']
